# %% [markdown]
# <a href="https://colab.research.google.com/github/aagam2704/distributed-computing/blob/main/Untitled49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
git clone https://github.com/ibm-granite/granite-geospatial-biomass.git
# Out:
#   File "/tmp/ipython-input-190577630.py", line 1
#     git clone https://github.com/ibm-granite/granite-geospatial-biomass.git
#         ^
# SyntaxError: invalid syntax
